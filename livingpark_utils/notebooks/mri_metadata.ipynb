# %% [markdown]
# # Introduction
#
# Many imaging studies require T1-weighted images with specific acquisition parameters, usually sagittal acquisition. In PPMI, metadata on MRI acquisition is available in file "Magnetic_Resonance_Imaging__MRI_.csv", however, this file does not contain detailed information about acquistion parameters.
#
# This notebook downloads acquisition parameters of 3D T1-weighted images from the PPMI imaging database, filters sagittal acquisition scans, and converts visit names used in the imaging database to the ones used in other PPMI metadata.
#
# The resulting file can be used to build imaging cohorts based on PPMI.

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the Python code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the Python code."></form>

# %% [markdown]
# # Data download
#
# Let's download information about PPMI 3D T1-weighted scans:

# %%
import os
import os.path as op
import pandas as pd
import ppmi_downloader

data_dir = op.join('inputs', 'study_files')

if not op.exists(data_dir):
    os.makedirs(data_dir)

mri_file_name = '3D_mri_info.csv'
required_files = [mri_file_name]
missing_files = [x for x in required_files if not op.exists(os.path.join(data_dir, x))]

if len(missing_files) > 0:
    ppmi = ppmi_downloader.PPMIDownloader()
    file_name = ppmi.download_3D_T1_info(destination_dir=data_dir, headless=False)
    assert(op.exists(op.join(data_dir, file_name)))
    os.rename(op.join(data_dir, file_name), op.join(data_dir, mri_file_name))
    ppmi.quit()

print('File downloaded')
# Out:
# PPMI login:  mathdugre@pm.me
# PPMI password:  ········
# LivingPark-utils|DEBUG|ppmi_downloader.py:106 in __init__()
#                        self.tempdir: <TemporaryDirectory '/tmp/tmpuzv0d_at'>
# LivingPark-utils|DEBUG|ppmi_downloader.py:117 in __init__()
#                        self.config_file: '.ppmi_config'
#                        config_file: '.ppmi_config'
# LivingPark-utils|DEBUG|ppmi_navigator.py:64 in click_button()
#                        'Click button': 'Click button'
#                        field: 'ida-cookie-policy-accept'
#                        debug_name: 'Cookie Policy'
# LivingPark-utils|DEBUG|ppmi_navigator.py:64 in click_button()
#                        'Click button': 'Click button'
#                        field: 'ida-cookie-policy-accept'
#                        debug_name: 'Cookie Policy'
# LivingPark-utils|DEBUG|ppmi_navigator.py:33 in wait_for_element_to_be_visible()
#                        'Wait for element to be visible': 'Wait for element to be visible'
#                        field: 'ida-user-username'
#                        BY: 'class name'
#                        debug_name: ''
# LivingPark-utils|DEBUG|ppmi_navigator.py:33 in wait_for_element_to_be_visible()
#                        'Wait for element to be visible': 'Wait for element to be visible'
#                        field: 'userEmail'
#                        BY: 'name'
#                        debug_name: ''
# LivingPark-utils|DEBUG|ppmi_navigator.py:48 in enter_data()
#                        'Enter data': 'Enter data'
#                        field: 'userEmail'
#                        debug_name: 'Email'
# LivingPark-utils|DEBUG|ppmi_navigator.py:33 in wait_for_element_to_be_visible()
#                        'Wait for element to be visible': 'Wait for element to be visible'
#                        field: 'userPassword'
#                        BY: 'name'
#                        debug_name: ''
# LivingPark-utils|DEBUG|ppmi_navigator.py:48 in enter_data()
#                        'Enter data': 'Enter data'
#                        field: 'userPassword'
#                        debug_name: 'Password'
# LivingPark-utils|DEBUG|ppmi_navigator.py:33 in wait_for_element_to_be_visible()
#                        'Wait for element to be visible': 'Wait for element to be visible'
#                        field: 'button'
#                        BY: 'tag name'
#                        debug_name: ''
# LivingPark-utils|DEBUG|ppmi_navigator.py:64 in click_button()
#                        'Click button': 'Click button'
#                        field: 'button'
#                        debug_name: 'Login button'
# LivingPark-utils|INFO|'Login Successful'
# LivingPark-utils|DEBUG|ppmi_navigator.py:64 in click_button()
#                        'Click button': 'Click button'
#                        field: 'ida-menu-option.sub-menu.search'
#                        debug_name: 'Search'
# LivingPark-utils|DEBUG|ppmi_navigator.py:376 in Search_AdvancedImageSearchbeta()
#                        not postcondition(): True
# LivingPark-utils|DEBUG|ppmi_navigator.py:64 in click_button()
#                        'Click button': 'Click button'
#                        field: "//*[text()='Advanced Image Search (beta)']"
#                        debug_name: 'Advanced Image Search (beta)'
# LivingPark-utils|DEBUG|ppmi_navigator.py:64 in click_button()
#                        'Click button': 'Click button'
#                        field: 'imgProtocol_checkBox1.Acquisition_Type.3D'
#                        debug_name: ''
# LivingPark-utils|DEBUG|ppmi_navigator.py:64 in click_button()
#                        'Click button': 'Click button'
#                        field: 'imgProtocol_checkBox1.Weighting.T1'
#                        debug_name: ''
# LivingPark-utils|DEBUG|ppmi_navigator.py:64 in click_button()
#                        'Click button': 'Click button'
#                        field: 'RESET_VISIT.0'
#                        debug_name: ''
# LivingPark-utils|DEBUG|ppmi_navigator.py:64 in click_button()
#                        'Click button': 'Click button'
#                        field: 'RESET_STUDY.0'
#                        debug_name: ''
# LivingPark-utils|DEBUG|ppmi_navigator.py:64 in click_button()
#                        'Click button': 'Click button'
#                        field: 'RESET_PROTOCOL_NUMERIC.imgProtocol_1_Field_Strength'
#                        debug_name: ''
# LivingPark-utils|DEBUG|ppmi_navigator.py:64 in click_button()
#                        'Click button': 'Click button'
#                        field: 'RESET_PROTOCOL_STRING.1_Acquisition_Plane'
#                        debug_name: ''
# LivingPark-utils|DEBUG|ppmi_navigator.py:64 in click_button()
#                        'Click button': 'Click button'
#                        field: 'advSearchQuery'
#                        debug_name: ''
# LivingPark-utils|DEBUG|ppmi_navigator.py:64 in click_button()
#                        'Click button': 'Click button'
#                        field: '//*[@type="button" and @value="CSV Download"]'
#                        debug_name: ''
# LivingPark-utils|INFO|f"Successfully downloaded file {filename}": 'Successfully downloaded file idaSearch_11_16_2022.csv'
# File downloaded

# %% [markdown]
# # Filter sagittal acquisitions
#
# PPMI scans were acquired using the following protocols:

# %%
pd.set_option('display.max_rows', 500)
mri_info = pd.read_csv(op.join(data_dir, mri_file_name))
mri_info.groupby('Description').count()
# Out:
#                                 Subject ID  Sex  Visit  Study Date  Age  \
# Description
# 3D SAG                                   2    2      2           2    2
# 3D SAG T1 MPRAGE                         4    4      4           4    4
# 3D SAG T1 MPRAGE_ND                      3    3      3           3    3
# 3D Sagittal T1                           7    7      7           7    7
# 3D T1                                   11   11     11          11   11
# 3D T1 MPRAGE                            14   14     14          14   14
# 3D T1-weighted                          53   53     53          53   53
# AX 3D FSPGR straight brain lab           1    1      1           1    1
# AX T1                                   11   11     11          11   11
# AX T1 SE C+                              1    1      1           1    1
# AXIAL T1 3D MPRAGE                       1    1      1           1    1
# Accelerated Sag IR-FSPGR                16   16     16          16   16
# COR                                      2    2      2           2    2
# Cal Head 24                              2    2      2           2    2
# Coronal                                  6    6      6           6    6
# FSPGR 3D SAG                            27   27     27          27   27
# MPRAGE                                  67   67     67          67   67
# MPRAGE - Sag                             4    4      4           4    4
# MPRAGE 2 ADNI                            1    1      1           1    1
# MPRAGE ADNI                             60   60     60          60   60
# MPRAGE GRAPPA                          794  794    794         794  794
# MPRAGE GRAPPA 2                         21   21     21          21   21
# MPRAGE GRAPPA2                          88   88     88          88   88
# MPRAGE GRAPPA2(adni)                     5    5      5           5    5
# MPRAGE GRAPPA_ND                        47   47     47          47   47
# MPRAGE Phantom GRAPPA2                   2    2      2           2    2
# MPRAGE Repeat                           34   34     34          34   34
# MPRAGE SAG                               7    7      7           7    7
# MPRAGE SAG IPAT ISO                      1    1      1           1    1
# MPRAGE SENSE2                            2    2      2           2    2
# MPRAGE T1 SAG                           20   20     20          20   20
# MPRAGE w/ GRAPPA                        12   12     12          12   12
# MPRAGE w/ GRAPPA 2                       1    1      1           1    1
# MPRAGE_64channel_p2                      1    1      1           1    1
# MPRAGE_ASO                               5    5      5           5    5
# MPRAGE_ASO_repeat                        1    1      1           1    1
# MPRAGE_GRAPPA                           96   96     96          96   96
# MPRAGE_GRAPPA2                           4    4      4           4    4
# MPRAGE_GRAPPA_ADNI                     101  101    101         101  101
# MPRAGE_SAG                               2    2      2           2    2
# MPRAGEadni                              34   34     34          34   34
# PPMI_MPRAGE_GRAPPA2                     24   24     24          24   24
# SAG                                      2    2      2           2    2
# SAG 3D FSPGR BRAVO STRAIGHT              2    2      2           2    2
# SAG 3D MPRAGE                           83   83     83          83   83
# SAG 3D MPRAGE RPT                        3    3      3           3    3
# SAG 3D SPGR                             15   15     15          15   15
# SAG 3D T1                               43   43     43          43   43
# SAG 3D T1 FSPGR                         34   34     34          34   34
# SAG 3D T1 MPRAGE                         3    3      3           3    3
# SAG 3D T1-weighted                       3    3      3           3    3
# SAG FSPGR 3D                            28   28     28          28   28
# SAG FSPGR 3D VOLUMETRIC T1               3    3      3           3    3
# SAG FSPGR BRAVO                          4    4      4           4    4
# SAG MPRAGE GRAPPA                       66   66     66          66   66
# SAG MPRAGE GRAPPA2-NEW2016               1    1      1           1    1
# SAG MPRAGE GRAPPA_ND                     9    9      9           9    9
# SAG SPGR                                 5    5      5           5    5
# SAG SPGR 3D                              1    1      1           1    1
# SAG T1 3D FSPGR                         32   32     32          32   32
# SAG T1 3D FSPGR 3RD REPEAT               1    1      1           1    1
# SAG T1 3D MPRAGE                        34   34     34          34   34
# SAG T1 3DMPRAGE                         18   18     18          18   18
# SAG T1 MPRAGE                            1    1      1           1    1
# STRUC BRAVO SAG3D ARC                    2    2      2           2    2
# Sag MPRAGE GRAPPA                       39   39     39          39   39
# Sag MPRAGE GRAPPA_ND                     6    6      6           6    6
# Sagittal 3D Accelerated MPRAGE           5    5      5           5    5
# T1                                      65   65     65          65   65
# T1 REPEAT                                4    4      4           4    4
# T1 Repeat                                2    2      2           2    2
# T1 repeat                                1    1      1           1    1
# T1-weighted, 3D VOLUMETRIC              12   12     12          12   12
# T1W_3D_FFE AX                            1    1      1           1    1
# T1W_3D_FFE COR                           1    1      1           1    1
# TRA                                      3    3      3           3    3
# Transverse                               3    3      3           3    3
# axial spgr                              19   19     19          19   19
# mprage                                   1    1      1           1    1
# rpt_PPMI_MPRAGE_GRAPPA2                  3    3      3           3    3
# sT1W_3D_TFE                             11   11     11          11   11
# sag 3D FSPGR BRAVO straight             17   17     17          17   17
# sag mprage                              35   35     35          35   35
# tra_T1_MPRAGE                            5    5      5           5    5
#
#                                 Imaging Protocol
# Description
# 3D SAG                                         2
# 3D SAG T1 MPRAGE                               4
# 3D SAG T1 MPRAGE_ND                            3
# 3D Sagittal T1                                 7
# 3D T1                                         11
# 3D T1 MPRAGE                                  14
# 3D T1-weighted                                53
# AX 3D FSPGR straight brain lab                 1
# AX T1                                         11
# AX T1 SE C+                                    1
# AXIAL T1 3D MPRAGE                             1
# Accelerated Sag IR-FSPGR                      16
# COR                                            2
# Cal Head 24                                    2
# Coronal                                        6
# FSPGR 3D SAG                                  27
# MPRAGE                                        67
# MPRAGE - Sag                                   4
# MPRAGE 2 ADNI                                  1
# MPRAGE ADNI                                   60
# MPRAGE GRAPPA                                794
# MPRAGE GRAPPA 2                               21
# MPRAGE GRAPPA2                                88
# MPRAGE GRAPPA2(adni)                           5
# MPRAGE GRAPPA_ND                              47
# MPRAGE Phantom GRAPPA2                         2
# MPRAGE Repeat                                 34
# MPRAGE SAG                                     7
# MPRAGE SAG IPAT ISO                            1
# MPRAGE SENSE2                                  2
# MPRAGE T1 SAG                                 20
# MPRAGE w/ GRAPPA                              12
# MPRAGE w/ GRAPPA 2                             1
# MPRAGE_64channel_p2                            1
# MPRAGE_ASO                                     5
# MPRAGE_ASO_repeat                              1
# MPRAGE_GRAPPA                                 96
# MPRAGE_GRAPPA2                                 4
# MPRAGE_GRAPPA_ADNI                           101
# MPRAGE_SAG                                     2
# MPRAGEadni                                    34
# PPMI_MPRAGE_GRAPPA2                           24
# SAG                                            2
# SAG 3D FSPGR BRAVO STRAIGHT                    2
# SAG 3D MPRAGE                                 83
# SAG 3D MPRAGE RPT                              3
# SAG 3D SPGR                                   15
# SAG 3D T1                                     43
# SAG 3D T1 FSPGR                               34
# SAG 3D T1 MPRAGE                               3
# SAG 3D T1-weighted                             3
# SAG FSPGR 3D                                  28
# SAG FSPGR 3D VOLUMETRIC T1                     3
# SAG FSPGR BRAVO                                4
# SAG MPRAGE GRAPPA                             66
# SAG MPRAGE GRAPPA2-NEW2016                     1
# SAG MPRAGE GRAPPA_ND                           9
# SAG SPGR                                       5
# SAG SPGR 3D                                    1
# SAG T1 3D FSPGR                               32
# SAG T1 3D FSPGR 3RD REPEAT                     1
# SAG T1 3D MPRAGE                              34
# SAG T1 3DMPRAGE                               18
# SAG T1 MPRAGE                                  1
# STRUC BRAVO SAG3D ARC                          2
# Sag MPRAGE GRAPPA                             39
# Sag MPRAGE GRAPPA_ND                           6
# Sagittal 3D Accelerated MPRAGE                 5
# T1                                            65
# T1 REPEAT                                      4
# T1 Repeat                                      2
# T1 repeat                                      1
# T1-weighted, 3D VOLUMETRIC                    12
# T1W_3D_FFE AX                                  1
# T1W_3D_FFE COR                                 1
# TRA                                            3
# Transverse                                     3
# axial spgr                                    19
# mprage                                         1
# rpt_PPMI_MPRAGE_GRAPPA2                        3
# sT1W_3D_TFE                                   11
# sag 3D FSPGR BRAVO straight                   17
# sag mprage                                    35
# tra_T1_MPRAGE                                  5

# %% [markdown]
# To keep only the sagittal acquisitions, we will remove the following protocols:

# %%
# Remove sequences that exactly match the following
removed_sequences=['COR', # coronal acquisitions
                   'Coronal', 
                   'Cal Head 24',  # not sure what this is
                   'Transverse',  # transverse (axial) acquisitions
                   'tra_T1_MPRAGE',
                   'TRA'
                  ]
print(removed_sequences)
# Out:
# ['COR', 'Coronal', 'Cal Head 24', 'Transverse', 'tra_T1_MPRAGE', 'TRA']

# %% [markdown]
# We will also remove the protocol names containing the following strings:

# %%
# Remove sequences containing the following strings
removed_sequences_contain = ['AX', 'axial', 'Phantom']
print(removed_sequences_contain)
# Out:
# ['AX', 'axial', 'Phantom']

# %% [markdown]
# We obtain the following list of protocols:

# %%
mri_info = mri_info[~mri_info['Description'].isin(removed_sequences)]
for s in removed_sequences_contain:
    mri_info = mri_info[~mri_info['Description'].str.contains(s)]
mri_info.groupby('Description').count()
# Out:
#                                 Subject ID  Sex  Visit  Study Date  Age  \
# Description
# 3D SAG                                   2    2      2           2    2
# 3D SAG T1 MPRAGE                         4    4      4           4    4
# 3D SAG T1 MPRAGE_ND                      3    3      3           3    3
# 3D Sagittal T1                           7    7      7           7    7
# 3D T1                                   11   11     11          11   11
# 3D T1 MPRAGE                            14   14     14          14   14
# 3D T1-weighted                          53   53     53          53   53
# Accelerated Sag IR-FSPGR                16   16     16          16   16
# FSPGR 3D SAG                            27   27     27          27   27
# MPRAGE                                  67   67     67          67   67
# MPRAGE - Sag                             4    4      4           4    4
# MPRAGE 2 ADNI                            1    1      1           1    1
# MPRAGE ADNI                             60   60     60          60   60
# MPRAGE GRAPPA                          794  794    794         794  794
# MPRAGE GRAPPA 2                         21   21     21          21   21
# MPRAGE GRAPPA2                          88   88     88          88   88
# MPRAGE GRAPPA2(adni)                     5    5      5           5    5
# MPRAGE GRAPPA_ND                        47   47     47          47   47
# MPRAGE Repeat                           34   34     34          34   34
# MPRAGE SAG                               7    7      7           7    7
# MPRAGE SAG IPAT ISO                      1    1      1           1    1
# MPRAGE SENSE2                            2    2      2           2    2
# MPRAGE T1 SAG                           20   20     20          20   20
# MPRAGE w/ GRAPPA                        12   12     12          12   12
# MPRAGE w/ GRAPPA 2                       1    1      1           1    1
# MPRAGE_64channel_p2                      1    1      1           1    1
# MPRAGE_ASO                               5    5      5           5    5
# MPRAGE_ASO_repeat                        1    1      1           1    1
# MPRAGE_GRAPPA                           96   96     96          96   96
# MPRAGE_GRAPPA2                           4    4      4           4    4
# MPRAGE_GRAPPA_ADNI                     101  101    101         101  101
# MPRAGE_SAG                               2    2      2           2    2
# MPRAGEadni                              34   34     34          34   34
# PPMI_MPRAGE_GRAPPA2                     24   24     24          24   24
# SAG                                      2    2      2           2    2
# SAG 3D FSPGR BRAVO STRAIGHT              2    2      2           2    2
# SAG 3D MPRAGE                           83   83     83          83   83
# SAG 3D MPRAGE RPT                        3    3      3           3    3
# SAG 3D SPGR                             15   15     15          15   15
# SAG 3D T1                               43   43     43          43   43
# SAG 3D T1 FSPGR                         34   34     34          34   34
# SAG 3D T1 MPRAGE                         3    3      3           3    3
# SAG 3D T1-weighted                       3    3      3           3    3
# SAG FSPGR 3D                            28   28     28          28   28
# SAG FSPGR 3D VOLUMETRIC T1               3    3      3           3    3
# SAG FSPGR BRAVO                          4    4      4           4    4
# SAG MPRAGE GRAPPA                       66   66     66          66   66
# SAG MPRAGE GRAPPA2-NEW2016               1    1      1           1    1
# SAG MPRAGE GRAPPA_ND                     9    9      9           9    9
# SAG SPGR                                 5    5      5           5    5
# SAG SPGR 3D                              1    1      1           1    1
# SAG T1 3D FSPGR                         32   32     32          32   32
# SAG T1 3D FSPGR 3RD REPEAT               1    1      1           1    1
# SAG T1 3D MPRAGE                        34   34     34          34   34
# SAG T1 3DMPRAGE                         18   18     18          18   18
# SAG T1 MPRAGE                            1    1      1           1    1
# STRUC BRAVO SAG3D ARC                    2    2      2           2    2
# Sag MPRAGE GRAPPA                       39   39     39          39   39
# Sag MPRAGE GRAPPA_ND                     6    6      6           6    6
# Sagittal 3D Accelerated MPRAGE           5    5      5           5    5
# T1                                      65   65     65          65   65
# T1 REPEAT                                4    4      4           4    4
# T1 Repeat                                2    2      2           2    2
# T1 repeat                                1    1      1           1    1
# T1-weighted, 3D VOLUMETRIC              12   12     12          12   12
# T1W_3D_FFE COR                           1    1      1           1    1
# mprage                                   1    1      1           1    1
# rpt_PPMI_MPRAGE_GRAPPA2                  3    3      3           3    3
# sT1W_3D_TFE                             11   11     11          11   11
# sag 3D FSPGR BRAVO straight             17   17     17          17   17
# sag mprage                              35   35     35          35   35
#
#                                 Imaging Protocol
# Description
# 3D SAG                                         2
# 3D SAG T1 MPRAGE                               4
# 3D SAG T1 MPRAGE_ND                            3
# 3D Sagittal T1                                 7
# 3D T1                                         11
# 3D T1 MPRAGE                                  14
# 3D T1-weighted                                53
# Accelerated Sag IR-FSPGR                      16
# FSPGR 3D SAG                                  27
# MPRAGE                                        67
# MPRAGE - Sag                                   4
# MPRAGE 2 ADNI                                  1
# MPRAGE ADNI                                   60
# MPRAGE GRAPPA                                794
# MPRAGE GRAPPA 2                               21
# MPRAGE GRAPPA2                                88
# MPRAGE GRAPPA2(adni)                           5
# MPRAGE GRAPPA_ND                              47
# MPRAGE Repeat                                 34
# MPRAGE SAG                                     7
# MPRAGE SAG IPAT ISO                            1
# MPRAGE SENSE2                                  2
# MPRAGE T1 SAG                                 20
# MPRAGE w/ GRAPPA                              12
# MPRAGE w/ GRAPPA 2                             1
# MPRAGE_64channel_p2                            1
# MPRAGE_ASO                                     5
# MPRAGE_ASO_repeat                              1
# MPRAGE_GRAPPA                                 96
# MPRAGE_GRAPPA2                                 4
# MPRAGE_GRAPPA_ADNI                           101
# MPRAGE_SAG                                     2
# MPRAGEadni                                    34
# PPMI_MPRAGE_GRAPPA2                           24
# SAG                                            2
# SAG 3D FSPGR BRAVO STRAIGHT                    2
# SAG 3D MPRAGE                                 83
# SAG 3D MPRAGE RPT                              3
# SAG 3D SPGR                                   15
# SAG 3D T1                                     43
# SAG 3D T1 FSPGR                               34
# SAG 3D T1 MPRAGE                               3
# SAG 3D T1-weighted                             3
# SAG FSPGR 3D                                  28
# SAG FSPGR 3D VOLUMETRIC T1                     3
# SAG FSPGR BRAVO                                4
# SAG MPRAGE GRAPPA                             66
# SAG MPRAGE GRAPPA2-NEW2016                     1
# SAG MPRAGE GRAPPA_ND                           9
# SAG SPGR                                       5
# SAG SPGR 3D                                    1
# SAG T1 3D FSPGR                               32
# SAG T1 3D FSPGR 3RD REPEAT                     1
# SAG T1 3D MPRAGE                              34
# SAG T1 3DMPRAGE                               18
# SAG T1 MPRAGE                                  1
# STRUC BRAVO SAG3D ARC                          2
# Sag MPRAGE GRAPPA                             39
# Sag MPRAGE GRAPPA_ND                           6
# Sagittal 3D Accelerated MPRAGE                 5
# T1                                            65
# T1 REPEAT                                      4
# T1 Repeat                                      2
# T1 repeat                                      1
# T1-weighted, 3D VOLUMETRIC                    12
# T1W_3D_FFE COR                                 1
# mprage                                         1
# rpt_PPMI_MPRAGE_GRAPPA2                        3
# sT1W_3D_TFE                                   11
# sag 3D FSPGR BRAVO straight                   17
# sag mprage                                    35

# %% [markdown]
# # Convert visit names

# %% [markdown]
# Let's use the following map to convert visit names to the codes used in PPMI metadata:

# %%
visit_map = {
    'Screening': 'SC',
    'Baseline': 'BL',
    'Month 12': 'V04',
    'Month 24': 'V06',
    'Month 36': 'V08',
    'Month 48': 'V10',
    'Symptomatic Therapy': 'ST',
    'Unscheduled Visit 01': 'U01',
    'Unscheduled Visit 02': 'U02',
    'Premature Withdrawal': 'PW'
}
print(visit_map)
# Out:
# {'Screening': 'SC', 'Baseline': 'BL', 'Month 12': 'V04', 'Month 24': 'V06', 'Month 36': 'V08', 'Month 48': 'V10', 'Symptomatic Therapy': 'ST', 'Unscheduled Visit 01': 'U01', 'Unscheduled Visit 02': 'U02', 'Premature Withdrawal': 'PW'}

# %% [markdown]
# We obtain the following distribution by visit code:

# %%
mri_info['Visit code'] = mri_info['Visit'].apply(lambda x: visit_map[x])
mri_info.groupby('Visit code').count()
# Out:
#             Subject ID   Sex  Visit  Study Date   Age  Description  \
# Visit code
# BL                1173  1173   1173        1173  1173         1173
# PW                   1     1      1           1     1            1
# SC                   4     4      4           4     4            4
# ST                  10    10     10          10    10           10
# U01                 10    10     10          10    10           10
# U02                  2     2      2           2     2            2
# V04                279   279    279         279   279          279
# V06                324   324    324         324   324          324
# V08                  2     2      2           2     2            2
# V10                359   359    359         359   359          359
#
#             Imaging Protocol
# Visit code
# BL                      1173
# PW                         1
# SC                         4
# ST                        10
# U01                       10
# U02                        2
# V04                      279
# V06                      324
# V08                        2
# V10                      359

# %% [markdown]
# Finally, let's save our table as csv file:

# %%
filename = 'MRI_info.csv'
mri_info.to_csv(op.join(data_dir, filename), index=False)
print(f'Saved in {filename}')
# Out:
# Saved in MRI_info.csv
