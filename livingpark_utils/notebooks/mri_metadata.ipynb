# %% [markdown]
# # Introduction
#
# Many imaging studies require T1-weighted images with specific acquisition parameters, usually sagittal acquisition. In PPMI, metadata on MRI acquisition is available in file "Magnetic_Resonance_Imaging__MRI_.csv", however, this file does not contain detailed information about acquistion parameters.
#
# This notebook downloads acquisition parameters of 3D T1-weighted images from the PPMI imaging database, filters sagittal acquisition scans, and converts visit names used in the imaging database to the ones used in other PPMI metadata.
#
# The resulting file can be used to build imaging cohorts based on PPMI.

# %% [markdown]
# # Data download
#
# Let's download information about PPMI 3D T1-weighted scans:

# %%
import livingpark_utils
import ppmi_downloader
import os


utils = livingpark_utils.LivingParkUtils()
utils.notebook_init()

mri_file_name = "3D_mri_info.csv"
if not os.path.exists(os.path.join(utils.study_files_dir, mri_file_name)):
    ppmi = ppmi_downloader.PPMIDownloader()
    file_name = ppmi.download_3D_T1_info(destination_dir=utils.study_files_dir)
    os.rename(
        os.path.join(utils.study_files_dir, file_name),
        os.path.join(utils.study_files_dir, mri_file_name),
    )
# Out:
# This notebook was run on 2023-02-10 02:10:58 UTC +0000

# %%
# import pandas as pd

# mri_file_name_all = '3D_mri_info_all.csv'
# all_images = pd.read_csv(os.path.join(utils.study_files_dir, mri_file_name_all))
# pd.unique(all_images['Description'])

# %% [markdown]
# # Filter non-T1 acquisitions
#
# The "Weighting" parameter in the Imaging Protocol field is not fully reliable as some T1 images have "Weighting=PD". Therefore we extract T1 images as the ones with "Weighting=T1" in their Imaging Protocol OR "T1" in their protocol description. We obtain the following list of protocol descriptions.

# %%
import pandas as pd

pd.set_option("display.max_rows", 500)
mri_info = pd.read_csv(os.path.join(utils.study_files_dir, mri_file_name))

# %%
# Keep only T1 images
mri_info = mri_info[
    mri_info["Imaging Protocol"].str.contains("Weighting=T1")
    | mri_info["Description"].str.contains("t1")
    | mri_info["Description"].str.contains("T1")
]
mri_info.groupby("Description").count()
# Out:
#                                 Subject ID  Sex  Visit  Study Date  Age  \
# Description
# 3D  T1w                                  2    2      2           2    2
# 3D  T1w,                                 1    1      1           1    1
# 3D SAG                                   2    2      2           2    2
# 3D SAG T1 MPRAGE                         6    6      6           6    6
# 3D SAG T1 MPRAGE_ND                      5    5      5           5    5
# 3D Sagittal T1                           7    7      7           7    7
# 3D T1                                   12   12     12          12   12
# 3D T1 MPRAGE                            19   19     19          19   19
# 3D T1 _weighted                         71   71     71          71   71
# 3D T1 weighted                           3    3      3           3    3
# 3D T1-WEIGHTED                           8    8      8           8    8
# 3D T1-Weighted                           2    2      2           2    2
# 3D T1-weighted                         262  262    262         262  262
# 3D T1-weighted_ND                       24   24     24          24   24
# 3D-T1-weighted                           3    3      3           3    3
# 3D-T1-weighted_SAGITAL                  29   29     29          29   29
# 3DT1weighted                             5    5      5           5    5
# 3D_T1-weighted                          29   29     29          29   29
# AX 3D FSPGR straight brain lab           1    1      1           1    1
# AX T1                                   11   11     11          11   11
# AX T1 SE C+                              1    1      1           1    1
# AXIAL T1 3D MPRAGE                       1    1      1           1    1
# Accelerated Sag IR-FSPGR                16   16     16          16   16
# COR                                      2    2      2           2    2
# Cal Head 24                              2    2      2           2    2
# Coronal                                  6    6      6           6    6
# FSPGR 3D SAG                            27   27     27          27   27
# MPRAGE                                  68   68     68          68   68
# MPRAGE - Sag                            13   13     13          13   13
# MPRAGE 2 ADNI                            1    1      1           1    1
# MPRAGE ADNI                             60   60     60          60   60
# MPRAGE GRAPPA                          794  794    794         794  794
# MPRAGE GRAPPA 2                         21   21     21          21   21
# MPRAGE GRAPPA2                          88   88     88          88   88
# MPRAGE GRAPPA2(adni)                     5    5      5           5    5
# MPRAGE GRAPPA_ND                        47   47     47          47   47
# MPRAGE Phantom GRAPPA2                   2    2      2           2    2
# MPRAGE Repeat                           34   34     34          34   34
# MPRAGE SAG                               7    7      7           7    7
# MPRAGE SAG IPAT ISO                      9    9      9           9    9
# MPRAGE SENSE2                            2    2      2           2    2
# MPRAGE T1 SAG                           20   20     20          20   20
# MPRAGE w/ GRAPPA                        12   12     12          12   12
# MPRAGE w/ GRAPPA 2                       1    1      1           1    1
# MPRAGE_                                  2    2      2           2    2
# MPRAGE_64channel_p2                      1    1      1           1    1
# MPRAGE_ASO                               5    5      5           5    5
# MPRAGE_ASO_repeat                        1    1      1           1    1
# MPRAGE_GRAPPA                           96   96     96          96   96
# MPRAGE_GRAPPA2                           4    4      4           4    4
# MPRAGE_GRAPPA_ADNI                     101  101    101         101  101
# MPRAGE_SAG                               2    2      2           2    2
# MPRAGEadni                              34   34     34          34   34
# PPMI_MPRAGE_GRAPPA2                     24   24     24          24   24
# SAG                                      2    2      2           2    2
# SAG 3D FSPGR BRAVO STRAIGHT              2    2      2           2    2
# SAG 3D MPRAGE                          132  132    132         132  132
# SAG 3D MPRAGE RPT                        3    3      3           3    3
# SAG 3D SPGR                             15   15     15          15   15
# SAG 3D T1                               66   66     66          66   66
# SAG 3D T1 FSPGR                         51   51     51          51   51
# SAG 3D T1 MPRAGE                         6    6      6           6    6
# SAG 3D T1-weighted                       6    6      6           6    6
# SAG FSPGR 3D                            28   28     28          28   28
# SAG FSPGR 3D VOLUMETRIC T1               3    3      3           3    3
# SAG FSPGR BRAVO                          4    4      4           4    4
# SAG MPRAGE GRAPPA                       66   66     66          66   66
# SAG MPRAGE GRAPPA2-NEW2016               1    1      1           1    1
# SAG MPRAGE GRAPPA_ND                     9    9      9           9    9
# SAG SPGR                                 5    5      5           5    5
# SAG SPGR 3D                              1    1      1           1    1
# SAG T1 3D FSPGR                         32   32     32          32   32
# SAG T1 3D FSPGR 3RD REPEAT               1    1      1           1    1
# SAG T1 3D MPRAGE                        34   34     34          34   34
# SAG T1 3DMPRAGE                         18   18     18          18   18
# SAG T1 MPRAGE                            1    1      1           1    1
# STRUC BRAVO SAG3D ARC                    2    2      2           2    2
# Sag MPRAGE GRAPPA                       39   39     39          39   39
# Sag MPRAGE GRAPPA_ND                     6    6      6           6    6
# Sagittal 3D Accelerated MPRAGE           7    7      7           7    7
# T1                                     320  320    320         320  320
# T1  Repeat                               5    5      5           5    5
# T1 REPEAT                               61   61     61          61   61
# T1 REPEAT 2                              1    1      1           1    1
# T1 REPEAT2                               1    1      1           1    1
# T1 Repeat                               92   92     92          92   92
# T1 repeat                                1    1      1           1    1
# T1-weighted, 3D VOLUMETRIC              21   21     21          21   21
# T1W_3D_FFE AX                            1    1      1           1    1
# T1W_3D_FFE COR                           1    1      1           1    1
# TRA                                      3    3      3           3    3
# Transverse                               3    3      3           3    3
# axial spgr                              19   19     19          19   19
# mprage                                   1    1      1           1    1
# rpt_PPMI_MPRAGE_GRAPPA2                  3    3      3           3    3
# sT1W_3D_TFE                             11   11     11          11   11
# sag 3D FSPGR BRAVO straight             17   17     17          17   17
# sag mprage                              35   35     35          35   35
# t1_mpr_ns_sag_p2_iso                    14   14     14          14   14
# tra_T1_MPRAGE                            5    5      5           5    5
#
#                                 Imaging Protocol
# Description
# 3D  T1w                                        2
# 3D  T1w,                                       1
# 3D SAG                                         2
# 3D SAG T1 MPRAGE                               6
# 3D SAG T1 MPRAGE_ND                            5
# 3D Sagittal T1                                 7
# 3D T1                                         12
# 3D T1 MPRAGE                                  19
# 3D T1 _weighted                               71
# 3D T1 weighted                                 3
# 3D T1-WEIGHTED                                 8
# 3D T1-Weighted                                 2
# 3D T1-weighted                               262
# 3D T1-weighted_ND                             24
# 3D-T1-weighted                                 3
# 3D-T1-weighted_SAGITAL                        29
# 3DT1weighted                                   5
# 3D_T1-weighted                                29
# AX 3D FSPGR straight brain lab                 1
# AX T1                                         11
# AX T1 SE C+                                    1
# AXIAL T1 3D MPRAGE                             1
# Accelerated Sag IR-FSPGR                      16
# COR                                            2
# Cal Head 24                                    2
# Coronal                                        6
# FSPGR 3D SAG                                  27
# MPRAGE                                        68
# MPRAGE - Sag                                  13
# MPRAGE 2 ADNI                                  1
# MPRAGE ADNI                                   60
# MPRAGE GRAPPA                                794
# MPRAGE GRAPPA 2                               21
# MPRAGE GRAPPA2                                88
# MPRAGE GRAPPA2(adni)                           5
# MPRAGE GRAPPA_ND                              47
# MPRAGE Phantom GRAPPA2                         2
# MPRAGE Repeat                                 34
# MPRAGE SAG                                     7
# MPRAGE SAG IPAT ISO                            9
# MPRAGE SENSE2                                  2
# MPRAGE T1 SAG                                 20
# MPRAGE w/ GRAPPA                              12
# MPRAGE w/ GRAPPA 2                             1
# MPRAGE_                                        2
# MPRAGE_64channel_p2                            1
# MPRAGE_ASO                                     5
# MPRAGE_ASO_repeat                              1
# MPRAGE_GRAPPA                                 96
# MPRAGE_GRAPPA2                                 4
# MPRAGE_GRAPPA_ADNI                           101
# MPRAGE_SAG                                     2
# MPRAGEadni                                    34
# PPMI_MPRAGE_GRAPPA2                           24
# SAG                                            2
# SAG 3D FSPGR BRAVO STRAIGHT                    2
# SAG 3D MPRAGE                                132
# SAG 3D MPRAGE RPT                              3
# SAG 3D SPGR                                   15
# SAG 3D T1                                     66
# SAG 3D T1 FSPGR                               51
# SAG 3D T1 MPRAGE                               6
# SAG 3D T1-weighted                             6
# SAG FSPGR 3D                                  28
# SAG FSPGR 3D VOLUMETRIC T1                     3
# SAG FSPGR BRAVO                                4
# SAG MPRAGE GRAPPA                             66
# SAG MPRAGE GRAPPA2-NEW2016                     1
# SAG MPRAGE GRAPPA_ND                           9
# SAG SPGR                                       5
# SAG SPGR 3D                                    1
# SAG T1 3D FSPGR                               32
# SAG T1 3D FSPGR 3RD REPEAT                     1
# SAG T1 3D MPRAGE                              34
# SAG T1 3DMPRAGE                               18
# SAG T1 MPRAGE                                  1
# STRUC BRAVO SAG3D ARC                          2
# Sag MPRAGE GRAPPA                             39
# Sag MPRAGE GRAPPA_ND                           6
# Sagittal 3D Accelerated MPRAGE                 7
# T1                                           320
# T1  Repeat                                     5
# T1 REPEAT                                     61
# T1 REPEAT 2                                    1
# T1 REPEAT2                                     1
# T1 Repeat                                     92
# T1 repeat                                      1
# T1-weighted, 3D VOLUMETRIC                    21
# T1W_3D_FFE AX                                  1
# T1W_3D_FFE COR                                 1
# TRA                                            3
# Transverse                                     3
# axial spgr                                    19
# mprage                                         1
# rpt_PPMI_MPRAGE_GRAPPA2                        3
# sT1W_3D_TFE                                   11
# sag 3D FSPGR BRAVO straight                   17
# sag mprage                                    35
# t1_mpr_ns_sag_p2_iso                          14
# tra_T1_MPRAGE                                  5

# %% [markdown]
# # Filter sagittal acquisitions

# %% [markdown]
# To keep only the sagittal acquisitions, we will remove the following protocols:

# %%
# Remove sequences that exactly match the following
removed_sequences = [
    "COR",  # coronal acquisitions
    "Coronal",
    "Cal Head 24",  # not sure what this is
    "Transverse",  # transverse (axial) acquisitions
    "tra_T1_MPRAGE",
    "TRA",
]
print(removed_sequences)
# Out:
# ['COR', 'Coronal', 'Cal Head 24', 'Transverse', 'tra_T1_MPRAGE', 'TRA']

# %% [markdown]
# We will also remove the protocol names containing the following strings:

# %%
# Remove sequences containing the following strings
removed_sequences_contain = ["AX", "Ax", "axial", "Phantom", "T2"]
print(removed_sequences_contain)
# Out:
# ['AX', 'Ax', 'axial', 'Phantom', 'T2']

# %% [markdown]
# We obtain the following list of protocols:

# %%
mri_info = mri_info[~mri_info["Description"].isin(removed_sequences)]
for s in removed_sequences_contain:
    mri_info = mri_info[~mri_info["Description"].str.contains(s)]
mri_info.groupby("Description").count()
# Out:
#                                 Subject ID  Sex  Visit  Study Date  Age  \
# Description
# 3D  T1w                                  2    2      2           2    2
# 3D  T1w,                                 1    1      1           1    1
# 3D SAG                                   2    2      2           2    2
# 3D SAG T1 MPRAGE                         6    6      6           6    6
# 3D SAG T1 MPRAGE_ND                      5    5      5           5    5
# 3D Sagittal T1                           7    7      7           7    7
# 3D T1                                   12   12     12          12   12
# 3D T1 MPRAGE                            19   19     19          19   19
# 3D T1 _weighted                         71   71     71          71   71
# 3D T1 weighted                           3    3      3           3    3
# 3D T1-WEIGHTED                           8    8      8           8    8
# 3D T1-Weighted                           2    2      2           2    2
# 3D T1-weighted                         262  262    262         262  262
# 3D T1-weighted_ND                       24   24     24          24   24
# 3D-T1-weighted                           3    3      3           3    3
# 3D-T1-weighted_SAGITAL                  29   29     29          29   29
# 3DT1weighted                             5    5      5           5    5
# 3D_T1-weighted                          29   29     29          29   29
# Accelerated Sag IR-FSPGR                16   16     16          16   16
# FSPGR 3D SAG                            27   27     27          27   27
# MPRAGE                                  68   68     68          68   68
# MPRAGE - Sag                            13   13     13          13   13
# MPRAGE 2 ADNI                            1    1      1           1    1
# MPRAGE ADNI                             60   60     60          60   60
# MPRAGE GRAPPA                          794  794    794         794  794
# MPRAGE GRAPPA 2                         21   21     21          21   21
# MPRAGE GRAPPA2                          88   88     88          88   88
# MPRAGE GRAPPA2(adni)                     5    5      5           5    5
# MPRAGE GRAPPA_ND                        47   47     47          47   47
# MPRAGE Repeat                           34   34     34          34   34
# MPRAGE SAG                               7    7      7           7    7
# MPRAGE SAG IPAT ISO                      9    9      9           9    9
# MPRAGE SENSE2                            2    2      2           2    2
# MPRAGE T1 SAG                           20   20     20          20   20
# MPRAGE w/ GRAPPA                        12   12     12          12   12
# MPRAGE w/ GRAPPA 2                       1    1      1           1    1
# MPRAGE_                                  2    2      2           2    2
# MPRAGE_64channel_p2                      1    1      1           1    1
# MPRAGE_ASO                               5    5      5           5    5
# MPRAGE_ASO_repeat                        1    1      1           1    1
# MPRAGE_GRAPPA                           96   96     96          96   96
# MPRAGE_GRAPPA2                           4    4      4           4    4
# MPRAGE_GRAPPA_ADNI                     101  101    101         101  101
# MPRAGE_SAG                               2    2      2           2    2
# MPRAGEadni                              34   34     34          34   34
# PPMI_MPRAGE_GRAPPA2                     24   24     24          24   24
# SAG                                      2    2      2           2    2
# SAG 3D FSPGR BRAVO STRAIGHT              2    2      2           2    2
# SAG 3D MPRAGE                          132  132    132         132  132
# SAG 3D MPRAGE RPT                        3    3      3           3    3
# SAG 3D SPGR                             15   15     15          15   15
# SAG 3D T1                               66   66     66          66   66
# SAG 3D T1 FSPGR                         51   51     51          51   51
# SAG 3D T1 MPRAGE                         6    6      6           6    6
# SAG 3D T1-weighted                       6    6      6           6    6
# SAG FSPGR 3D                            28   28     28          28   28
# SAG FSPGR 3D VOLUMETRIC T1               3    3      3           3    3
# SAG FSPGR BRAVO                          4    4      4           4    4
# SAG MPRAGE GRAPPA                       66   66     66          66   66
# SAG MPRAGE GRAPPA2-NEW2016               1    1      1           1    1
# SAG MPRAGE GRAPPA_ND                     9    9      9           9    9
# SAG SPGR                                 5    5      5           5    5
# SAG SPGR 3D                              1    1      1           1    1
# SAG T1 3D FSPGR                         32   32     32          32   32
# SAG T1 3D FSPGR 3RD REPEAT               1    1      1           1    1
# SAG T1 3D MPRAGE                        34   34     34          34   34
# SAG T1 3DMPRAGE                         18   18     18          18   18
# SAG T1 MPRAGE                            1    1      1           1    1
# STRUC BRAVO SAG3D ARC                    2    2      2           2    2
# Sag MPRAGE GRAPPA                       39   39     39          39   39
# Sag MPRAGE GRAPPA_ND                     6    6      6           6    6
# Sagittal 3D Accelerated MPRAGE           7    7      7           7    7
# T1                                     320  320    320         320  320
# T1  Repeat                               5    5      5           5    5
# T1 REPEAT                               61   61     61          61   61
# T1 REPEAT 2                              1    1      1           1    1
# T1 Repeat                               92   92     92          92   92
# T1 repeat                                1    1      1           1    1
# T1-weighted, 3D VOLUMETRIC              21   21     21          21   21
# T1W_3D_FFE COR                           1    1      1           1    1
# mprage                                   1    1      1           1    1
# rpt_PPMI_MPRAGE_GRAPPA2                  3    3      3           3    3
# sT1W_3D_TFE                             11   11     11          11   11
# sag 3D FSPGR BRAVO straight             17   17     17          17   17
# sag mprage                              35   35     35          35   35
# t1_mpr_ns_sag_p2_iso                    14   14     14          14   14
#
#                                 Imaging Protocol
# Description
# 3D  T1w                                        2
# 3D  T1w,                                       1
# 3D SAG                                         2
# 3D SAG T1 MPRAGE                               6
# 3D SAG T1 MPRAGE_ND                            5
# 3D Sagittal T1                                 7
# 3D T1                                         12
# 3D T1 MPRAGE                                  19
# 3D T1 _weighted                               71
# 3D T1 weighted                                 3
# 3D T1-WEIGHTED                                 8
# 3D T1-Weighted                                 2
# 3D T1-weighted                               262
# 3D T1-weighted_ND                             24
# 3D-T1-weighted                                 3
# 3D-T1-weighted_SAGITAL                        29
# 3DT1weighted                                   5
# 3D_T1-weighted                                29
# Accelerated Sag IR-FSPGR                      16
# FSPGR 3D SAG                                  27
# MPRAGE                                        68
# MPRAGE - Sag                                  13
# MPRAGE 2 ADNI                                  1
# MPRAGE ADNI                                   60
# MPRAGE GRAPPA                                794
# MPRAGE GRAPPA 2                               21
# MPRAGE GRAPPA2                                88
# MPRAGE GRAPPA2(adni)                           5
# MPRAGE GRAPPA_ND                              47
# MPRAGE Repeat                                 34
# MPRAGE SAG                                     7
# MPRAGE SAG IPAT ISO                            9
# MPRAGE SENSE2                                  2
# MPRAGE T1 SAG                                 20
# MPRAGE w/ GRAPPA                              12
# MPRAGE w/ GRAPPA 2                             1
# MPRAGE_                                        2
# MPRAGE_64channel_p2                            1
# MPRAGE_ASO                                     5
# MPRAGE_ASO_repeat                              1
# MPRAGE_GRAPPA                                 96
# MPRAGE_GRAPPA2                                 4
# MPRAGE_GRAPPA_ADNI                           101
# MPRAGE_SAG                                     2
# MPRAGEadni                                    34
# PPMI_MPRAGE_GRAPPA2                           24
# SAG                                            2
# SAG 3D FSPGR BRAVO STRAIGHT                    2
# SAG 3D MPRAGE                                132
# SAG 3D MPRAGE RPT                              3
# SAG 3D SPGR                                   15
# SAG 3D T1                                     66
# SAG 3D T1 FSPGR                               51
# SAG 3D T1 MPRAGE                               6
# SAG 3D T1-weighted                             6
# SAG FSPGR 3D                                  28
# SAG FSPGR 3D VOLUMETRIC T1                     3
# SAG FSPGR BRAVO                                4
# SAG MPRAGE GRAPPA                             66
# SAG MPRAGE GRAPPA2-NEW2016                     1
# SAG MPRAGE GRAPPA_ND                           9
# SAG SPGR                                       5
# SAG SPGR 3D                                    1
# SAG T1 3D FSPGR                               32
# SAG T1 3D FSPGR 3RD REPEAT                     1
# SAG T1 3D MPRAGE                              34
# SAG T1 3DMPRAGE                               18
# SAG T1 MPRAGE                                  1
# STRUC BRAVO SAG3D ARC                          2
# Sag MPRAGE GRAPPA                             39
# Sag MPRAGE GRAPPA_ND                           6
# Sagittal 3D Accelerated MPRAGE                 7
# T1                                           320
# T1  Repeat                                     5
# T1 REPEAT                                     61
# T1 REPEAT 2                                    1
# T1 Repeat                                     92
# T1 repeat                                      1
# T1-weighted, 3D VOLUMETRIC                    21
# T1W_3D_FFE COR                                 1
# mprage                                         1
# rpt_PPMI_MPRAGE_GRAPPA2                        3
# sT1W_3D_TFE                                   11
# sag 3D FSPGR BRAVO straight                   17
# sag mprage                                    35
# t1_mpr_ns_sag_p2_iso                          14

# %% [markdown]
# # Convert visit names

# %% [markdown]
# Let's use the following map to convert visit names to the codes used in PPMI metadata:

# %%
visit_map = {
    "Screening": "SC",
    "Baseline": "BL",
    "Month 6": "V02",
    "Month 12": "V04",
    "Month 24": "V06",
    "Month 36": "V08",
    "Month 48": "V10",
    "Symptomatic Therapy": "ST",
    "Unscheduled Visit 01": "U01",
    "Unscheduled Visit 02": "U02",
    "Premature Withdrawal": "PW",
}
print(visit_map)
# Out:
# {'Screening': 'SC', 'Baseline': 'BL', 'Month 6': 'V02', 'Month 12': 'V04', 'Month 24': 'V06', 'Month 36': 'V08', 'Month 48': 'V10', 'Symptomatic Therapy': 'ST', 'Unscheduled Visit 01': 'U01', 'Unscheduled Visit 02': 'U02', 'Premature Withdrawal': 'PW'}

# %% [markdown]
# We obtain the following distribution by visit code:

# %%
mri_info["Visit code"] = mri_info["Visit"].apply(lambda x: visit_map[x])
mri_info.groupby("Visit code").count()
# Out:
#             Subject ID   Sex  Visit  Study Date   Age  Description  \
# Visit code
# BL                1960  1960   1960        1960  1960         1960
# PW                   1     1      1           1     1            1
# SC                   4     4      4           4     4            4
# ST                  10    10     10          10    10           10
# U01                 10    10     10          10    10           10
# U02                  2     2      2           2     2            2
# V02                  1     1      1           1     1            1
# V04                344   344    344         344   344          344
# V06                332   332    332         332   332          332
# V08                  2     2      2           2     2            2
# V10                442   442    442         442   442          442
#
#             Imaging Protocol
# Visit code
# BL                      1960
# PW                         1
# SC                         4
# ST                        10
# U01                       10
# U02                        2
# V02                        1
# V04                      344
# V06                      332
# V08                        2
# V10                      442

# %% [markdown]
# Finally, let's save our table as csv file:

# %%
filename = "MRI_info.csv"
mri_info.to_csv(os.path.join(utils.study_files_dir, filename), index=False)
print(f"Saved in {filename}")
# Out:
# Saved in MRI_info.csv
